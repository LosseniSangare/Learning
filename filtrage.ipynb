# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datasets/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
sup_20 = df['total_bill']>20
sup_20
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[sup_20].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
#
#          Payer Name         CC Number Payment ID
# 2    Travis Walters  6011812112971322    Sun4458
# 3  Nathaniel Harris  4676137647685994    Sun5260
# 4      Tonya Carter  4832732618637221    Sun2251
# 5        Erik Smith   213140353657882    Sun9679
# 7       Robert Buck  3514785077705092    Sun8157

# %%
condition1 = (df['total_bill'] > 20) & (df['sex']=='Male')
condition1
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240    False
# 241     True
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df[condition1].head()
# Out:
#     total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 2        21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5        25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 7        26.88  3.12  Male     No  Sun  Dinner     4              6.72
# 15       21.58  3.92  Male     No  Sun  Dinner     2             10.79
#
#           Payer Name         CC Number Payment ID
# 2     Travis Walters  6011812112971322    Sun4458
# 3   Nathaniel Harris  4676137647685994    Sun5260
# 5         Erik Smith   213140353657882    Sun9679
# 7        Robert Buck  3514785077705092    Sun8157
# 15    Matthew Reilly   180073029785069    Sun1878

# %%
jours = ['Fri','San','Sun']
condition2 = df['day'].isin(jours)
condition2
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[condition2].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Méthodes Utiles

# %%
str(1234567890)[-4:]
# Out:
# '7890'

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(13245689090)
# Out:
# '9090'

# %%
df['last_fort']= df['CC Number'].apply(last_four)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_fort
# ...

# %%
def dolar(prix):
    if(prix<=10):
        return '$'
    elif (prix> 10 and prix <=30):
        return '$$'
    else :
        return '$$'

# %%
df['dolar']= df['price_per_person'].apply(dolar)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_fort dolar
# ...

# %% [markdown]
# ### Apply sur des colonne multiples

# %%
def quality(total_bill,tip):
    if(tip/total_bill >0.25):
        return 'Generous'
    else : return 'Other'

# %%
quality(16.99,1.01)
# Out:
# 'Other'

# %%
df["Quality"] = df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df= df.drop('Quality', axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_fort dolar
# 0  Christy Cunningham  3560325168603410    Sun2959      3410     $
# 1      Douglas Tucker  4478071379779230    Sun4608      9230     $
# 2      Travis Walters  6011812112971322    Sun4458      1322     $
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221     $

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_fort dolar Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410     $   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230     $   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322     $   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221     $   Other

# %%
dfn=df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
dfn.describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_fort dolar Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410     $   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230     $   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322     $   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221     $   Other

# %%
df.sort_values('tip', ascending=False) # croissant pour True
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
# ...

# %%
df.sort_values(['tip','total_bill'])# ascendin = true par defaut
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
max_tip = df['tip'].max() # idem pour min()
max_tip
# Out:
# 10.0

# %%
index_max_tip = df['tip'].idxmax() #idem pour idmin()
index_max_tip
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_fort                       8236
# dolar                             $$
# Quality                        Other
# Name: 170, dtype: object

# %%
df.corr() #correlation
# Out:
# C:\Users\sangarea\AppData\Local\Temp\ipykernel_23032\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique() # renvoi le nombre d'instance
                    # idem que len(df['day'].unique())
# Out:
# 4

# %%
df['sex'].replace('Female','F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
my_map={'Male' : 'M','Female' : 'F'}
df['sex'].map(my_map)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df_dup = df.append([df.iloc[241],df.iloc[242]])
df_dup
# Out:
# C:\Users\sangarea\AppData\Local\Temp\ipykernel_23032\3841507998.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dup = df.append([df.iloc[241],df.iloc[242]])
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# ...

# %%
df_dup[df_dup.duplicated()]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#        Payer Name         CC Number Payment ID last_fort dolar Quality
# 241    Keith Wong  6011891618747196    Sat3880      7196    $$   Other
# 242  Dennis Dixon     4375220550950      Sat17      0950     $   Other

# %%
df_dup = df_dup.drop_duplicates()
df_dup
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_fort dolar Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410     $   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230     $   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322     $   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221     $   Other

# %%
df['tip'].between(5,10)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
df[df['tip'].between(5,10,inclusive=True)]
# Out:
# C:\Users\sangarea\AppData\Local\Temp\ipykernel_23032\1189696434.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['tip'].between(5,10,inclusive=True)]
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 46        22.23   5.00    Male     No   Sun  Dinner     2             11.12
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# ...

# %%
df.nlargest(7,'tip') # same than nmalles(2,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
#
#             Payer Name         CC Number Payment ID last_fort dolar   Quality
# 170      Gregory Clark  5473850968388236    Sat1954      8236    $$     Other
# 212    Alex Williamson      676218815212    Sat4590      5212    $$     Other
# 23      Lance Peterson  3542584061609808     Sat239      9808     $     Other
# ...

# %%
df.sample(5) # 5 ligne aléatoire de mon dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4              6.47
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
#
#          Payer Name         CC Number Payment ID last_fort dolar Quality
# 241      Keith Wong  6011891618747196    Sat3880      7196    $$   Other
# 215    Jessica Owen     4726904879471    Sat6983      9471     $   Other
# 211  Christopher Li  6011962464150569    Sat6735      0569     $   Other
# 196     Eric Martin    30442491190342   Thur9862      0342     $   Other
# 237    Thomas Brown  4284722681265508    Sat2929      5508    $$   Other

# %%
df.sample(frac=0.05) # 5 pourcent de notre dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 117       10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
# 37        16.93  3.07  Female     No   Sat  Dinner     3              5.64
# 157       25.00  3.75  Female     No   Sun  Dinner     4              6.25
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 84        15.98  2.03    Male     No  Thur   Lunch     2              7.99
# 39        31.27  5.00    Male     No   Sat  Dinner     3             10.42
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# ...
